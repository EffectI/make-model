# %%
import pandas as pd

df_a = pd.read_csv("make-model/experiments/temp_submission/submission_roberta.csv")
df_b = pd.read_csv("make-model/experiments/temp_submission/submission_test.csv")

corr_df = pd.DataFrame({
    'Model_A': df_a['generated'],
    'Model_B': df_b['generated']
})

print(corr_df.corr())
# Out:
#           Model_A   Model_B
# Model_A  1.000000  0.703695
# Model_B  0.703695  1.000000
